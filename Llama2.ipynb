# %% [markdown]
# <a href="https://colab.research.google.com/github/Kira1108/PromptEngineering/blob/main/Llama2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import clear_output

# !pip install transformers torch accelerate

clear_output()

# %% [markdown]
# Get an access token from facebook meta, huggingface, when login in to huggingface, use that token.

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !huggingface-cli whoami
# Out:
# Kira1108

# %%
from transformers import AutoTokenizer
from transformers import pipeline
import transformers
import torch

model_name = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token = True)



llama_pipeline = pipeline(
    "text-generation",
    model=model_name,
    device_map = "auto",
    torch_dtype = torch.float16,
    )
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
def get_completion(prompt,**kwargs):

    default_params = dict(
        do_sample = True,
        top_k = 10,
        num_return_sequences = 1,
        eos_token_id = tokenizer.eos_token_id,
        max_length = 1024
    )

    default_params.update(kwargs)

    return llama_pipeline(prompt, **default_params)[0]['generated_text']

# %%
from IPython.display import Markdown

Markdown(get_completion(prompt = "How can I study english more effectively?"))
# Out:
# How can I study english more effectively?
#
# Answer: There are several ways to study English more effectively, including:
#
# 1. Setting clear goals: Identify what you want to achieve in your English learning journey, such as improving your speaking, writing, or reading skills.
# 2. Creating a study schedule: Plan out dedicated time each day or week to study English, and stick to it.
# 3. Using a variety of study materials: Incorporate different resources, such as textbooks, language learning apps, podcasts, and videos, into your study routine.
# 4. Practicing consistently: Make a habit of practicing English regularly, even if it's just for a few minutes each day.
# 5. Immersing yourself in the language: Listen to English music, watch English movies or TV shows, and try to speak English with native speakers or language exchange partners.
# ...
